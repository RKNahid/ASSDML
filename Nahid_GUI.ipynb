# %% [markdown]
# <a href="https://colab.research.google.com/github/RKNahid/Automated-Sleep-Stage-Detection-using-Machine-Learning-Algorithm/blob/main/Nahid_GUI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Mount Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Predict Sleep Stage

# %%
#@title Main Engine

Input_DATA_Path = '/content/drive/MyDrive/Project/GUI/Datas/Series_Data.csv' #@param {type:"string"}
Select_Algorithm = 'XGBoosting (Accu: 0.94)' #@param ["Random Forest (Accu: 0.92)", "XGBoosting (Accu: 0.94)","GradientBoosting (Accu: 0.88)"]



import numpy as np
import pandas as pd
from tqdm.notebook import tqdm
from joblib import Parallel, delayed
import joblib


def load_model(model_name):
  return joblib.load(model_name)


model_path_dict = {
    "Random Forest (Accu: 0.92)": "/content/drive/MyDrive/Project/GUI/rf.sav",
    "XGBoosting (Accu: 0.94)": "/content/drive/MyDrive/Project/GUI/xgb.sav",
    "GradientBoosting (Accu: 0.88)": "/content/drive/MyDrive/Project/GUI/gb.sav"
}



dataset = pd.read_csv(Input_DATA_Path)
model = load_model(model_path_dict[Select_Algorithm])

class_dict={0:"NREM",1:"REM"}
for i in tqdm(range(dataset.shape[0])):
  print("For Row Number ",i," predicted class: ",class_dict[model.predict(dataset.loc[i:i,:])[0]])
# Out:
#   0%|          | 0/17820 [00:00<?, ?it/s]
# Streaming output truncated to the last 5000 lines.
# For Row Number  316  predicted class:  NREM
# For Row Number  317  predicted class:  NREM
# For Row Number  318  predicted class:  NREM
# For Row Number  319  predicted class:  NREM
# For Row Number  320  predicted class:  REM
# For Row Number  321  predicted class:  NREM
# For Row Number  322  predicted class:  NREM
# For Row Number  323  predicted class:  NREM
# For Row Number  324  predicted class:  NREM
# For Row Number  325  predicted class:  NREM
# For Row Number  326  predicted class:  NREM
# For Row Number  327  predicted class:  NREM
# For Row Number  328  predicted class:  NREM
# For Row Number  329  predicted class:  REM
# For Row Number  330  predicted class:  REM
# For Row Number  331  predicted class:  NREM
# For Row Number  332  predicted class:  NREM
# For Row Number  333  predicted class:  NREM
# For Row Number  334  predicted class:  NREM
# ...
